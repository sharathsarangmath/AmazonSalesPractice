# %%
import pandas as pd

# %%
import glob

# %%
#get data file name
path1=r'/Users/sharathsarangmath/Desktop/AmazonSales/Data/PM'
path2=r'/Users/sharathsarangmath/Desktop/AmazonSales/Data/HL'

# %%
filename1=glob.glob(path1 +"/*.csv")
filename2=glob.glob(path2+"/*.csv")

# %%
li=[]
for f in filename1:
    df=pd.read_csv(f,index_col=0,header=0)
    li.append(df)

# %%
frame=pd.concat(li,axis=0,ignore_index=False)

# %%
frame
# Out:
#                                          Product Name        ASIN  \
# #
# 1   SourceDIY 111 Water Balloons Bombs Self Sealin...  B086YYYX9T
# 2    Original Zuru Bunch of Balloons (Color May Vary)  B01H4P8CEO
# 3   264 Pack Water Balloons Self Sealing Easy & Fa...  B07T7J563Y
# 4   132 Pack Water Balloons Self Sealing Easy & Fa...  B07SGXPCP6
# 5   100 Fast Fill Magic ZURU Bunch o Water Balloon...  B01C63PCMY
# 6   ZURU Bunch O Balloons 420 Water Balloon Summer...  B07BTLC3LY
# 7   Zuru Bunch O Balloons - Fill 100 Water Balloon...  B01E942SZ2
# 8   Zuru Bunch O Balloons Instant 100 Self-Sealing...  B012P4NCOE
# 9   X-Shot&nbsp;&ndash;&nbsp;Pack of 100, Bunch O ...  B01EYS249I
# 10  ZURU BUNCH O BALLOONS 5636 Bunch O Balloons Wa...  B01LXUS4F7
# 11  ZURU BUNCH O BALLOONS 5632 Bunch O Balloons Sl...  B01LXJ2MWL
# 12  Marvel Official Zuru Bunch O Balloons Avengers...  B07C5LF18W
# 13  Splash Toys BOMB A O 31102 Catapult for Precis...  B01N26AJGR
# ...

# %%
li1=[]
for f in filename2:
    df1=pd.read_csv(f,index_col=0,header=0)
    li1.append(df1)

# %%
frame2=pd.concat(li1,axis=0,ignore_index=False)

# %%
frame2
# Out:
#                                   Brand  \
# ASIN
# B0876TLFJW                    ($) VNEED
# B086WBXRSH                  ($) Merkisa
# B087FVYD4N                 ($) Amzyigou
# B0856T2RVL                     Yinuoday
# B000LZ0Y82                      BABYMAD
# B00NVMIO02                        Braun
# B0866K2RM4                     Liliannh
# B086K5SCQB                       RAXFLY
# B0871DZ2BH                        VNEED
# B0862BL5FV                           HR
# B0867CR4SV                     Liliannh
# B086W84HRM                        ancke
# B07PGCS9Z4                ($) MojiDecor
# B07S3VG2LH                ($) femometer
# B0867CR4SV                 ($) Liliannh
# B00P70F36Y                          C63
# B07PGCS9Z4                    MojiDecor
# B085WW2Q5L                     PigHappy
# B0862DGL4K                     Yinuoday
# B086W7H5WM                        ancke
# B086XCZB3X                       Yivans
# B086V9DZ3F                        SONRU
# ...

# %%
# !git init
# Out:
# Initialized empty Git repository in /Users/sharathsarangmath/Desktop/AmazonSales/.git/

# %%
# !git status
